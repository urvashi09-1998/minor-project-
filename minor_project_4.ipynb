# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_stockprice = pd.read_excel('/Users/urvashi/Library/Containers/com.microsoft.Excel/Data/Downloads/1729258-1613615-Stock_Price_data_set_(1).xlsx')
df_stockprice
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1    2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2    2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3    2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4    2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...         ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#           Volume
# 0     11896100.0
# 1     12595800.0
# ...

# %%
df_stockprice.count()
# Out:
# Date         1009
# Open         1009
# High         1009
# Low          1009
# Close        1009
# Adj Close    1009
# Volume       1009
# dtype: int64

# %%
df_stockprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   datetime64[ns]
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 55.3 KB

# %%
df_stockprice.describe(include = 'all')
# Out:
# /var/folders/r3/n5ympc1n1fjbybbdqnyblpgw0000gn/T/ipykernel_13203/948382957.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_stockprice.describe(include = 'all')
#                        Date         Open         High          Low  \
# count                  1009  1009.000000  1009.000000  1009.000000
# unique                 1009          NaN          NaN          NaN
# top     2018-02-05 00:00:00          NaN          NaN          NaN
# freq                      1          NaN          NaN          NaN
# first   2018-02-05 00:00:00          NaN          NaN          NaN
# last    2022-02-04 00:00:00          NaN          NaN          NaN
# mean                    NaN   419.059673   425.320703   412.374044
# std                     NaN   108.537532   109.262960   107.555867
# ...

# %%
df_stockprice.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object

# %%
# Hunting missing values
df_stockprice.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# viewing how many 'total' null values are there in the dataset
df_stockprice.isnull().sum().sum()
# Out:
# 0

# %%
df_stockprice.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
# Plotting a histogram to view how the 'close' feature is laid out.

plt.figure(figsize = (15, 8))
sns.histplot(data = df_stockprice , x = "Close", bins = 50)
plt.show()

# %%
plt.figure(figsize = (15 , 8))
sns.histplot(data = df_stockprice , x = "Date" , kde = True)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Count'>

# %%
plt.figure(figsize=(15,8))
plt.scatter(df_stockprice ['Date'],df_stockprice ['Close'])
plt.xlabel('Date')
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')

# %%
plt.figure(figsize=(15,8))
plt.scatter(df_stockprice ['Open'],df_stockprice ['Close'])
plt.xlabel('Open')
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')

# %%
plt.figure(figsize=(15,8))
plt.scatter(df_stockprice ['High'],df_stockprice ['Close'])
plt.xlabel('High')
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')

# %%
plt.figure(figsize=(15,8))
plt.scatter(df_stockprice ['Low'],df_stockprice ['Close'])
plt.xlabel('Low')
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')

# %%
plt.figure(figsize=(15,8))
plt.scatter(df_stockprice ['Low'],df_stockprice ['Date'])
plt.xlabel('Low')
plt.ylabel('Date')
# Out:
# Text(0, 0.5, 'Date')

# %%
plt.figure(figsize=(15,8))
plt.scatter(df_stockprice ['High'],df_stockprice ['Date'])
plt.xlabel('High')
plt.ylabel('Date')
# Out:
# Text(0, 0.5, 'Date')

# %%
plt.figure(figsize = (12 , 6))
sns.heatmap(df_stockprice.corr() , annot = True , cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
df_stockprice['Date'][1008]
# Out:
# Timestamp('2022-02-04 00:00:00')

# %%
train_data, test_data = df_stockprice[0:int(len(df_stockprice)*0.8)], df_stockprice[int(len(df_stockprice)*0.8):]
plt.figure(figsize=(12,7))
plt.title('Tesla Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.plot(df_stockprice['Open'], 'blue', label='Training Data')
plt.plot(test_data['Open'], 'green', label='Testing Data')
plt.xticks(np.arange(0,1008, 300), df_stockprice['Date'][0:1008:300])
plt.legend()

# %%
def smape_kun(y_true, y_pred):
    return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) + np.abs(y_true))))

# %%
train_ar = train_data['Open'].values
test_ar = test_data['Open'].values

# https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
history = [x for x in train_ar]
print(type(history))
predictions = list()
for t in range(len(test_ar)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_ar[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
error2 = smape_kun(test_ar, predictions)
print('Symmetric mean absolute percentage error: %.3f' % error2)
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 8>()
#       7 predictions = list()
#       8 for t in range(len(test_ar)):
# ----> 9     model = ARIMA(history, order=(5,1,0))
#      10     model_fit = model.fit(disp=0)
#      11     output = model_fit.forecast()
#
# NameError: name 'ARIMA' is not defined

# %%
plt.figure(figsize=(12,7))
plt.plot(df_stockprice['Open'], 'green', color='blue', label='Training Data')
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['Open'], color='red', label='Actual Price')
plt.title('Tesla Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.xticks(np.arange(0,1008, 300), df_stockprice['Date'][0:1008:300])
plt.legend()
# Out:
# /var/folders/r3/n5ympc1n1fjbybbdqnyblpgw0000gn/T/ipykernel_13203/435052346.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "green" (-> color=(0.0, 0.5019607843137255, 0.0, 1.0)). The keyword argument will take precedence.
#   plt.plot(df_stockprice['Open'], 'green', color='blue', label='Training Data')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 3>()
#       1 plt.figure(figsize=(12,7))
#       2 plt.plot(df_stockprice['Open'], 'green', color='blue', label='Training Data')
# ----> 3 plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed',
#       4          label='Predicted Price')
#       5 plt.plot(test_data.index, test_data['Open'], color='red', label='Actual Price')
#       6 plt.title('Tesla Prices Prediction')
#
# ...
